# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dt=pd.read_csv('/content/AAPL.csv')

# %%
dt.head()
# Out:
#          Date  Open  High   Low  Close(t)     Volume      SD20  Upper_Band  \
# 0  2005-10-17  6.66  6.69  6.50      6.60  154208600  0.169237    6.827473
# 1  2005-10-18  6.57  6.66  6.44      6.45  152397000  0.168339    6.819677
# 2  2005-10-19  6.43  6.78  6.32      6.78  252170800  0.180306    6.861112
# 3  2005-10-20  6.72  6.97  6.71      6.93  339440500  0.202674    6.931847
# 4  2005-10-21  7.02  7.03  6.83      6.87  199181500  0.216680    6.974860
#
#    Lower_Band  S_Close(t-1)  ...  QQQ_MA10  QQQ_MA20  QQQ_MA50  SnP_Close  \
# 0    6.150527          6.67  ...    33.692   33.9970   34.2690    1190.10
# 1    6.146323          6.60  ...    33.570   33.9525   34.2466    1178.14
# 2    6.139888          6.45  ...    33.562   33.9600   34.2330    1195.76
# 3    6.121153          6.78  ...    33.567   33.9455   34.2190    1177.80
# 4    6.108140          6.93  ...    33.586   33.9365   34.2034    1179.59
#
# ...

# %%
dt.describe()
# Out:
#               Open         High          Low     Close(t)        Volume  \
# count  3732.000000  3732.000000  3732.000000  3732.000000  3.732000e+03
# mean     87.199989    88.093232    86.335801    87.256589  1.143350e+08
# std      79.017999    79.952065    78.265419    79.189743  9.931555e+07
# min       6.390000     6.530000     6.190000     6.260000  1.136200e+07
# 25%      22.575000    22.895000    22.160000    22.532500  3.714862e+07
# 50%      67.140000    67.650000    66.490000    67.075000  8.545600e+07
# 75%     117.555000   118.350000   116.730000   117.650000  1.603878e+08
# max     457.720000   464.170000   455.710000   460.040000  8.432424e+08
#
#               SD20   Upper_Band   Lower_Band  S_Close(t-1)  S_Close(t-2)  ...  \
# count  3732.000000  3732.000000  3732.000000   3732.000000   3732.000000  ...
# mean      2.639050    91.457990    80.901789     87.135107     87.015758  ...
# std       3.237696    82.563527    72.153572     78.965148     78.749784  ...
# ...

# %%
dt.shape
# Out:
# (3732, 64)

# %%
dt.isnull()
# Out:
#        Date   Open   High    Low  Close(t)  Volume   SD20  Upper_Band  \
# 0     False  False  False  False     False   False  False       False
# 1     False  False  False  False     False   False  False       False
# 2     False  False  False  False     False   False  False       False
# 3     False  False  False  False     False   False  False       False
# 4     False  False  False  False     False   False  False       False
# ...     ...    ...    ...    ...       ...     ...    ...         ...
# 3727  False  False  False  False     False   False  False       False
# 3728  False  False  False  False     False   False  False       False
# 3729  False  False  False  False     False   False  False       False
# 3730  False  False  False  False     False   False  False       False
# 3731  False  False  False  False     False   False  False       False
#
#       Lower_Band  S_Close(t-1)  ...  QQQ_MA10  QQQ_MA20  QQQ_MA50  SnP_Close  \
# ...

# %%
dt['Close(t)'].plot(figsize=(10, 7))
plt.title("Stock Price", fontsize=17)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
dt.dropna(inplace=True)

# %%
dt.isnull().sum()
# Out:
# Date             0
# Open             0
# High             0
# Low              0
# Close(t)         0
#                 ..
# SnP(t-5)         0
# DJIA_Close       0
# DJIA(t-1))       0
# DJIA(t-5)        0
# Close_forcast    0
# Length: 64, dtype: int64

# %%
dt.shape
dt = dt.drop(columns='Date')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-55a7b50f4373> in <module>
#       1 dt.shape
# ----> 2 dt = dt.drop(columns='Date')
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
X=dt.drop(columns='Close_forcast')

# %%
y=dt['Close_forcast']

# %%
X
# Out:
#         Open    High     Low  Close(t)     Volume       SD20  Upper_Band  \
# 0       6.66    6.69    6.50      6.60  154208600   0.169237    6.827473
# 1       6.57    6.66    6.44      6.45  152397000   0.168339    6.819677
# 2       6.43    6.78    6.32      6.78  252170800   0.180306    6.861112
# 3       6.72    6.97    6.71      6.93  339440500   0.202674    6.931847
# 4       7.02    7.03    6.83      6.87  199181500   0.216680    6.974860
# ...      ...     ...     ...       ...        ...        ...         ...
# 3727  452.82  454.70  441.17    444.45   49453300  27.954399  455.316298
# 3728  450.40  455.10  440.00    450.91   53100900  29.847338  462.586675
# 3729  447.88  449.93  436.43    437.50   46975600  30.576290  466.543079
# 3730  441.99  453.10  441.19    452.04   41486200  32.050532  472.583564
# 3731  457.72  464.17  455.71    460.04   52520500  33.532634  479.279768
#
#       Lower_Band  S_Close(t-1)  S_Close(t-2)  ...  QQQ(t-5)  QQQ_MA10  \
# ...

# %%
y
# Out:
# 0         6.45
# 1         6.78
# 2         6.93
# 3         6.87
# 4         7.01
#          ...
# 3727    450.91
# 3728    437.50
# 3729    452.04
# 3730    460.04
# 3731    459.63
# Name: Close_forcast, Length: 3732, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-616f85601133> in <module>
# ----> 1 lr.fit(X_train,y_train)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
c=lr.intercept_
c
# Out:
# -7.70844436605767

# %%
m=lr.coef_
m
# Out:
# array([-7.04065853e-02,  4.22645641e-01,  1.87157201e-01, -6.57885986e-03,
#        -8.74365684e-11,  5.77453127e-03,  1.41856415e-01,  1.18758289e-01,
#        -5.36362496e-01, -1.05940559e-01, -8.98589425e-02, -1.33444754e-02,
#        -3.70047820e-02, -5.16086768e-01, -1.59675383e-01,  1.30307340e-01,
#        -4.59809755e-02, -2.31754219e-02,  3.16745747e-01,  3.16745747e-01,
#         3.16745747e-01,  3.16745747e-01,  3.16745747e-01,  2.57526368e+00,
#        -2.32200380e+00, -7.25217914e-02, -1.65149949e-03,  3.29626396e-11,
#        -1.73495521e-02,  6.74501660e-03,  1.52274707e-03,  1.52274735e-03,
#        -2.06857884e-01, -3.48871598e-10,  2.83697510e-11,  4.67766311e-02,
#         1.76916459e-02, -4.70989292e-02,  1.00572820e-02, -9.55788650e-02,
#         1.76933439e-01,  1.75399493e-01, -1.43585034e-01,  1.40427296e-01,
#         3.98570066e-14,  1.63084369e-02,  2.77319492e-03,  1.38463196e+00,
# ...

# %%
y_predict_train=lr.predict(X_train)

# %%
y_predict_train
# Out:
# array([ 24.34465217,   8.25254712, 100.74314296, ...,  70.35767278,
#         90.76747249, 101.94813455])

# %%
plt.scatter(y_train,y_predict_train)
plt.xlabel("Actual Annual Railfall")
plt.ylabel("Predicted Annual Rainfall")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_predict_train)
# Out:
# 0.9992967094156308

# %%
y_pred_test=lr.predict(X_test)

# %%
plt.scatter(y_test,y_pred_test)
plt.xlabel("Actual Annual Railfall")
plt.ylabel("Predicted Annual Rainfall")
plt.show()

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.9993235261335213

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train,y_predict_train)
# Out:
# 0.9912137207509196

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred_test)
# Out:
# 0.9794240745955689

# %%
from sklearn import svm

# %%
h1=svm.SVR()

# %%
h1.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a1d2a0af496b> in <module>
# ----> 1 h1.fit(X_train,y_train)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     188             check_consistent_length(X, y)
#     189         else:
# --> 190             X, y = self._validate_data(
#     191                 X,
#     192                 y,
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...
